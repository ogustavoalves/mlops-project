# %%
import mlflow
from mlflow.models import infer_signature
import pandas as pd
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC
from sklearn.neural_network import MLPClassifier

from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
# Leitura da base
dataset_path = '../data/raw/heart.csv'
dataset = pd.read_csv(dataset_path)
# Sanity test - 5 primeiros registros
dataset.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   52    1   0       125   212    0        1      168      0      1.0      2
# 1   53    1   0       140   203    1        0      155      1      3.1      0
# 2   70    1   0       145   174    0        1      125      1      2.6      0
# 3   61    1   0       148   203    0        1      161      0      0.0      2
# 4   62    0   0       138   294    1        1      106      0      1.9      1
#
#    ca  thal  target
# 0   2     3       0
# 1   0     3       0
# 2   0     3       0
# 3   1     3       0
# 4   3     2       0

# %%
X = dataset.iloc[:, 0:13].values
y = dataset.iloc[:, 13].values

# %%
X_train, X_test, y_train, y_test, = train_test_split(X, y, test_size=0.2, random_state=0)

# %%
# Melhores parâmetros definidos pelo cross-validation/tunning de hiperparâmetros
tree_params = {
    'criterion': 'entropy', 
    'min_samples_leaf':1, 
    'min_samples_split': 5,
    'splitter':'best'
}

rf_params = {
    'criterion': 'entropy',
    'min_samples_leaf': 1,
    'n_estimators': 40
}

gb_params = {
    'criterion': 'friedman_mse', 
    'learning_rate': 0.1,
    'loss': 'exponential',
    'n_estimators': 300
}

knn_params = {
    'n_neighbors': 20,
    'p': 1
}

lr_params = {
    'C': 1.0,
    'solver': 'lbfgs',
    'tol': 0.0001
}

svm_params = {
    'C': 1.5,
    'kernel': 'rbf',
    'tol': 0.001
}

nn_params = {
    'activation': 'relu',
    'batch_size': 10,
    'solver': 'adam'
}

# %%
mlflow.set_tracking_uri(uri='http://localhost:5000')
experiment_name = '(test) Heart disease experiment'
mlflow.set_experiment(experiment_name)
# Out:
# <Experiment: artifact_location='file:///app/mlruns/351092206928158599', creation_time=1764086541062, experiment_id='351092206928158599', last_update_time=1764086541062, lifecycle_stage='active', name='(test) Heart disease experiment', tags={}>

# %%
def train_and_log_models(estimator, X_train, X_test, y_train, y_test, params, dataset, dataset_path):

    mlflow_dataset = mlflow.data.from_pandas(
        dataset, 
        source=dataset_path,
        name=dataset_path.split('/')[-1]
    )
    
    estimator_name = estimator.__name__
    estimator = estimator(**params)
    estimator.fit(X_train, y_train)
    y_pred = estimator.predict(X_test)
    
    
    with mlflow.start_run():
        mlflow.log_params(params)
        
        mlflow.log_metric('Accuracy', accuracy_score(y_test, y_pred))
        mlflow.log_metric('Precision', precision_score(y_test, y_pred))
        mlflow.log_metric('Recall', recall_score(y_test, y_pred))
        mlflow.log_metric('F1-Score', f1_score(y_test, y_pred))
        
        mlflow.log_input(mlflow_dataset, context='raw-data')
        
        signature = infer_signature(X_train, estimator.predict(X_test))
        
        model_info = mlflow.sklearn.log_model(
            sk_model=estimator,
            signature=signature, 
            input_example=X_test[[0]],
            registered_model_name=estimator_name
        )
        
            
        print(f'Caminho do artefato registrado: {model_info.artifact_path}')
        print(f'URI do modelo registrado: {model_info.model_uri}')

# %%
train_and_log_models(DecisionTreeClassifier, X_train, X_test, y_train, y_test, tree_params, dataset, dataset_path)
# Out:
# 🏃 View run salty-finch-850 at: http://localhost:5000/#/experiments/351092206928158599/runs/640b45f74e734a529616531c7645af02
# 🧪 View experiment at: http://localhost:5000/#/experiments/351092206928158599
# ---------------------------------------------------------------------------
# PermissionError                           Traceback (most recent call last)
# Cell In[18], line 1
# ----> 1 train_and_log_models(DecisionTreeClassifier, X_train, X_test, y_train, y_test, tree_params, dataset, dataset_path)
#
# Cell In[17], line 27, in train_and_log_models(estimator, X_train, X_test, y_train, y_test, params, dataset, dataset_path)
#      23 mlflow.log_input(mlflow_dataset, context='raw-data')
#      25 signature = infer_signature(X_train, estimator.predict(X_test))
# ---> 27 model_info = mlflow.sklearn.log_model(
#      28     sk_model=estimator,
#      29     signature=signature,
#      30     input_example=X_test[[0]],
#      31     registered_model_name=estimator_name
#      32 )
#      35 print(f'Caminho do artefato registrado: {model_info.artifact_path}')
#      36 print(f'URI do modelo registrado: {model_info.model_uri}')
#
# File ~/Documents/Github/mlops_project/venv/lib/python3.10/site-packages/mlflow/sklearn/__init__.py:426, in log_model(sk_model, artifact_path, conda_env, code_paths, serialization_format, registered_model_name, signature, input_example, await_registration_for, pip_requirements, extra_pip_requirements, pyfunc_predict_fn, metadata, params, tags, model_type, step, model_id, name)
#     334 @format_docstring(LOG_MODEL_PARAM_DOCS.format(package_name="scikit-learn"))
#     335 def log_model(
#     336     sk_model,
#    (...)
#     355     name: Optional[str] = None,
#     356 ):
#     357     """
#     358     Log a scikit-learn model as an MLflow artifact for the current run. Produces an MLflow Model
#     359     containing the following flavors:
#    (...)
#     424
#     425     """
# --> 426     return Model.log(
#     427         artifact_path=artifact_path,
#     428         name=name,
#     429         flavor=mlflow.sklearn,
#     430         sk_model=sk_model,
#     431         conda_env=conda_env,
#     432         code_paths=code_paths,
#     433         serialization_format=serialization_format,
#     434         registered_model_name=registered_model_name,
#     435         signature=signature,
#     436         input_example=input_example,
#     437         await_registration_for=await_registration_for,
#     438         pip_requirements=pip_requirements,
#     439         extra_pip_requirements=extra_pip_requirements,
#     440         pyfunc_predict_fn=pyfunc_predict_fn,
#     441         metadata=metadata,
#     442         params=params,
#     443         tags=tags,
#     444         model_type=model_type,
#     445         step=step,
#     446         model_id=model_id,
#     447     )
#
# File ~/Documents/Github/mlops_project/venv/lib/python3.10/site-packages/mlflow/models/model.py:1286, in Model.log(cls, artifact_path, flavor, registered_model_name, await_registration_for, metadata, run_id, resources, auth_policy, prompts, name, model_type, params, tags, step, model_id, **kwargs)
#    1283     # mlflow_model is updated, rewrite the MLmodel file
#    1284     mlflow_model.save(os.path.join(local_path, MLMODEL_FILE_NAME))
# -> 1286 client.log_model_artifacts(model.model_id, local_path)
#    1287 # If the model was previously identified as external, delete the tag because
#    1288 # the model now has artifacts in MLflow Model format
#    1289 if model.tags.get(MLFLOW_MODEL_IS_EXTERNAL, "false").lower() == "true":
#
# File ~/Documents/Github/mlops_project/venv/lib/python3.10/site-packages/mlflow/tracking/client.py:5514, in MlflowClient.log_model_artifacts(self, model_id, local_dir)
#    5503 def log_model_artifacts(self, model_id: str, local_dir: str) -> None:
#    5504     """
#    5505     Upload a set of artifacts to the specified logged model.
#    5506
#    (...)
#    5512         None
#    5513     """
# -> 5514     return self._tracking_client.log_model_artifacts(model_id, local_dir)
#
# File ~/Documents/Github/mlops_project/venv/lib/python3.10/site-packages/mlflow/tracking/_tracking_service/client.py:864, in TrackingServiceClient.log_model_artifacts(self, model_id, local_dir)
#     863 def log_model_artifacts(self, model_id: str, local_dir: str) -> None:
# --> 864     self._get_artifact_repo(model_id, resource="logged_model").log_artifacts(local_dir)
#
# File ~/Documents/Github/mlops_project/venv/lib/python3.10/site-packages/mlflow/store/artifact/local_artifact_repo.py:66, in LocalArtifactRepository.log_artifacts(self, local_dir, artifact_path)
#      62 artifact_dir = (
#      63     os.path.join(self.artifact_dir, artifact_path) if artifact_path else self.artifact_dir
#      64 )
#      65 if not os.path.exists(artifact_dir):
# ---> 66     mkdir(artifact_dir)
#      67 shutil.copytree(src=local_dir, dst=artifact_dir, dirs_exist_ok=True)
#
# File ~/Documents/Github/mlops_project/venv/lib/python3.10/site-packages/mlflow/utils/file_utils.py:209, in mkdir(root, name)
#     207 except OSError as e:
#     208     if e.errno != errno.EEXIST or not os.path.isdir(target):
# --> 209         raise e
#     210 return target
#
# File ~/Documents/Github/mlops_project/venv/lib/python3.10/site-packages/mlflow/utils/file_utils.py:206, in mkdir(root, name)
#     204 target = os.path.join(root, name) if name is not None else root
#     205 try:
# --> 206     os.makedirs(target, exist_ok=True)
#     207 except OSError as e:
#     208     if e.errno != errno.EEXIST or not os.path.isdir(target):
#
# File /usr/lib/python3.10/os.py:215, in makedirs(name, mode, exist_ok)
#     213 if head and tail and not path.exists(head):
#     214     try:
# --> 215         makedirs(head, exist_ok=exist_ok)
#     216     except FileExistsError:
#     217         # Defeats race condition when another thread created the path
#     218         pass
#
# File /usr/lib/python3.10/os.py:215, in makedirs(name, mode, exist_ok)
#     213 if head and tail and not path.exists(head):
#     214     try:
# --> 215         makedirs(head, exist_ok=exist_ok)
#     216     except FileExistsError:
#     217         # Defeats race condition when another thread created the path
#     218         pass
#
#     [... skipping similar frames: makedirs at line 215 (2 times)]
#
# File /usr/lib/python3.10/os.py:215, in makedirs(name, mode, exist_ok)
#     213 if head and tail and not path.exists(head):
#     214     try:
# --> 215         makedirs(head, exist_ok=exist_ok)
#     216     except FileExistsError:
#     217         # Defeats race condition when another thread created the path
#     218         pass
#
# File /usr/lib/python3.10/os.py:225, in makedirs(name, mode, exist_ok)
#     223         return
#     224 try:
# --> 225     mkdir(name, mode)
#     226 except OSError:
#     227     # Cannot rely on checking for EEXIST, since the operating system
#     228     # could give priority to other errors like EACCES or EROFS
#     229     if not exist_ok or not path.isdir(name):
#
# PermissionError: [Errno 13] Permission denied: '/app'

# %% [markdown]
# # Heart Disease Dataset Studies

# %%
import pickle
import traceback
import pandas as pd
import mlflow
from mlflow.models import infer_signature
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, roc_auc_score
from sklearn.pipeline import Pipeline
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import OneHotEncoder, OrdinalEncoder, StandardScaler
from sklearn.model_selection import GridSearchCV
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC
from sklearn.neural_network import MLPClassifier

# %% [markdown]
# ## About the Dataset
#
# **Column Descriptions:**
#
# - **age**: Patient's age.
# - **sex**: Patient's gender.
# - **cp (chest pain type)**: Type of chest pain. Possible values: 0, 1, 2, or 3.
# - **trestbps (resting blood pressure)**: Patient's resting blood pressure.
# - **chol (serum cholesterol in mg/dl)**: Total serum cholesterol level (in mg/dl).
# - **fbs (fasting blood sugar > 120 mg/dl)**: Blood sugar level after an 8-hour fast. If greater than 120 mg/dl, the value is 1; otherwise, 0.
# - **restecg (resting electrocardiographic results)**: Resting electrocardiogram results.
#   - 0 = Normal
#   - 1 = May indicate cardiac ischemia (lack of oxygenation to the heart)
#   - 2 = Significant abnormalities, such as left ventricular hypertrophy (LVH), hypertension, etc.
# - **thalach (maximum heart rate achieved)**: Maximum heart rate per minute recorded during the examination.
# - **exang (exercise induced angina)**: Exercise-induced chest pain caused by reduced blood flow to the heart muscle. Possible values: 0 or 1.
# - **oldpeak (ST depression induced by exercise relative to rest)**: ST-segment depression on the electrocardiogram (ECG) observed during exercise compared to rest. May indicate the presence of Coronary Artery Disease (CAD).
# - **slope (the slope of the peak exercise ST segment)**: The slope of the ST segment at peak exercise.
# - **ca (number of major vessels colored by fluoroscopy)**: Number of major blood vessels visible during a fluoroscopy exam (a real-time X-ray imaging technique). Possible values: 0, 1, 2, or 3.
# - **thal**: Results of tests assessing blood flow to the heart.
#   - 0 = Normal
#   - 1 = Fixed defect (permanently impaired flow)
#   - 2 = Reversible defect (temporarily impaired flow, but recoverable)
# - **target**: Indicates the presence of heart disease in the patient.
#   - 0 = No disease
#   - 1 = Disease present
# ```

# %% [markdown]
# ---

# %% [markdown]
# ## Basic data understanding

# %%
# Read dataset
dataset_path = '../data/raw/heart.csv'
dataset = pd.read_csv(dataset_path)
# Sanity test
dataset.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   52    1   0       125   212    0        1      168      0      1.0      2
# 1   53    1   0       140   203    1        0      155      1      3.1      0
# 2   70    1   0       145   174    0        1      125      1      2.6      0
# 3   61    1   0       148   203    0        1      161      0      0.0      2
# 4   62    0   0       138   294    1        1      106      0      1.9      1
#
#    ca  thal  target
# 0   2     3       0
# 1   0     3       0
# 2   0     3       0
# 3   1     3       0
# 4   3     2       0

# %%
# Get best hiperparameters already saved -- to avoid running grid_search_cv
with open('../data/raw/best_params.pkl', 'rb') as f:
    best_params_dict = pickle.load(f)

# %%
# Sanity test
best_params_dict
# Out:
# {'DecisionTreeClassifier_best_params': (Pipeline(steps=[('prep',
#                    ColumnTransformer(transformers=[('categorical',
#                                                     OrdinalEncoder(handle_unknown='use_encoded_value',
#                                                                    unknown_value=-1),
#                                                     ['sex', 'cp', 'fbs',
#                                                      'restecg', 'exang', 'slope',
#                                                      'ca', 'thal']),
#                                                    ('numerical', 'passthrough',
#                                                     ['age', 'trestbps', 'chol',
#                                                      'thalach', 'oldpeak'])])),
#                   ('classifier', DecisionTreeClassifier(splitter='random'))]),
#   {'classifier__criterion': 'gini',
#    'classifier__min_samples_leaf': 1,
# ...

# %%
dataset.columns
# Out:
# Index(['age', 'sex', 'cp', 'trestbps', 'chol', 'fbs', 'restecg', 'thalach',
#        'exang', 'oldpeak', 'slope', 'ca', 'thal', 'target'],
#       dtype='object')

# %%
dataset.shape
# Out:
# (1025, 14)

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1025 entries, 0 to 1024
# Data columns (total 14 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       1025 non-null   int64
#  1   sex       1025 non-null   int64
#  2   cp        1025 non-null   int64
#  3   trestbps  1025 non-null   int64
#  4   chol      1025 non-null   int64
#  5   fbs       1025 non-null   int64
#  6   restecg   1025 non-null   int64
#  7   thalach   1025 non-null   int64
#  8   exang     1025 non-null   int64
#  9   oldpeak   1025 non-null   float64
#  10  slope     1025 non-null   int64
#  11  ca        1025 non-null   int64
#  12  thal      1025 non-null   int64
#  13  target    1025 non-null   int64
# dtypes: float64(1), int64(13)
# memory usage: 112.2 KB

# %%
X = dataset.iloc[:, 0:13]
y = dataset.iloc[:, 13]

# %%
# Spliting X and y
X_train, X_test,  y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=0)

# %%
y_train.shape
# Out:
# (820,)

# %%
y_test.shape
# Out:
# (205,)

# %% [markdown]
# ## Pipelines
#
# Creating a pipeline that best fits each model needs -- setting the preprocessor with the right encoders to improve it's performance.

# %%
# Separating numerical and categorical type columns
numerical_cols = ['age', 'trestbps', 'chol', 'thalach', 'oldpeak']
categorical_cols = []
for col in dataset.columns:
    if col in numerical_cols or col == 'target':
        continue
    categorical_cols.append(col)

# %%
categorical_cols
# Out:
# ['sex', 'cp', 'fbs', 'restecg', 'exang', 'slope', 'ca', 'thal']

# %% [markdown]
# ### Preprocessing Rationale
#
# To optimize performance across different algorithms, I have designed three specific preprocessing pipelines based on how each model interprets data:
#
# #### Tree-Based Models (Decision Tree, Random Forest, Gradient Boosting)
# * **Ordinal Encoding:** These models function by splitting nodes based on feature thresholds. Ordinal encoding is preferred here because it maintains a low dimensionality (unlike One-Hot Encoding) while allowing the tree to find optimal split points.
# * **No Scaling:** Tree algorithms are **scale-invariant**. Since they evaluate each feature independently to find the best split, the relative magnitude or range of different features (e.g., Age vs. Cholesterol) does not influence the model's logic or accuracy.
#
# #### Distance-Based Models (KNN)
# * **One-Hot Encoding (OHE):** K-Nearest Neighbors relies on calculating the distance between data points. OHE is essential because it treats categories as equidistant, preventing the model from assuming a mathematical relationship or "rank" between categorical values.
# * **Standard Scaling:** Because KNN uses **Euclidean distance**, features with larger numerical ranges would disproportionately dominate the calculation. Scaling ensures that all features contribute equally to the distance metric.
#
# #### Linear & Neural Models (Logistic Regression, SVC, MLP)
# * **One-Hot Encoding:** These models learn a weight (coefficient) for each input. OHE allows the model to capture the independent effect of each category on the target variable.
# * **Standard Scaling:** These algorithms typically use **Gradient Descent** for optimization. Features with different scales can create an "elongated" loss function, making it difficult for the optimizer to converge. Scaling transforms the loss surface into a more symmetric shape, leading to faster and more stable convergence.

# %%
# Decision Tree, Random Forest, Gradient Boosting
prep_tree = ColumnTransformer(
    transformers=[
        ('categorical', OrdinalEncoder(
            handle_unknown='use_encoded_value',
            unknown_value=-1  # needed when handle_unknown='use_encoded_value'
        ), categorical_cols),
        ('numerical', 'passthrough', numerical_cols)
    ]
)

# KNN
prep_knn = ColumnTransformer(
    transformers=[
        ('categorical', OneHotEncoder(
            handle_unknown='use_encoded_value'), categorical_cols),
        ('numerical', StandardScaler(), numerical_cols)
    ]
)

# Logistic Regressor, SVC, MLPClassifier
prep_linear = ColumnTransformer(
    transformers=[
        ('categorical', OneHotEncoder(handle_unknown='ignore'), categorical_cols),
        ('numerical', StandardScaler(), numerical_cols)
    ]
)

# %% [markdown]
# ---

# %% [markdown]
# ## Cross validation / Hyperparameters Tuning

# %%
pipes_and_params = {
        'DecisionTreeClassifier': (
            Pipeline([
                ('prep', prep_tree), 
                ('classifier', DecisionTreeClassifier())
        ]),{
            'classifier__criterion': ['gini', 'entropy'],
            'classifier__splitter': ['best', 'random'],
            'classifier__min_samples_split': [2, 5, 10],
            'classifier__min_samples_leaf': [1, 5, 10]
        }
    ),
        'RandomForestClassifier': (
            Pipeline([
                ('prep', prep_tree), 
                ('classifier', RandomForestClassifier())
        ]),{
            'classifier__criterion': ['gini', 'entropy'],
            'classifier__n_estimators': [10, 40, 100, 150],
            'classifier__min_samples_split': [2, 5, 10],
            'classifier__min_samples_leaf': [1, 5, 10]
        }
    ),
        'GradientBoostingClassifier': (
            Pipeline([
                ('prep', prep_tree), 
                ('classifier', GradientBoostingClassifier())
        ]), {
            'classifier__loss': ['log_loss', 'exponential'],
            'classifier__learning_rate': [0.1, 0.01, 0.001, 0.0001],
            'classifier__n_estimators': [25, 50, 100, 200, 300, 500],
            'classifier__criterion': ['friedman_mse', 'squared_error']
        }
    ),
        'KNN': (
            Pipeline([
                ('prep', prep_linear), 
                ('classifier', KNeighborsClassifier())
        ]),{
            'classifier__n_neighbors': [3, 5, 10, 20],
            'classifier__p': [1, 2]
        }
    ),
        'LogisticRegression': (
            Pipeline([
                ('prep', prep_linear), 
                ('classifier', LogisticRegression(max_iter=2000))
        ]),{
            'classifier__tol': [0.0001, 0.00001, 0.000001],
            'classifier__C': [1.0, 1.5, 2.0],
            'classifier__solver': ['lbfgs', 'sag', 'saga']
        }
    ),
        'SVC': (
            Pipeline([
                ('prep', prep_linear), 
                ('classifier', SVC(probability=True))
        ]),{
            'classifier__tol': [0.001, 0.0001, 0.00001],
            'classifier__C': [1.0, 1.5, 2.0],
            'classifier__kernel': ['rbf', 'linear', 'poly', 'sigmoid']
        }
    ),
        'MLPC': (
        Pipeline([
            ('prep', prep_linear), 
            ('classifier', MLPClassifier(max_iter=3500))
        ]),{
            'classifier__activation': ['relu', 'logistic', 'tanh'],
            'classifier__solver': ['adam', 'sgd'],
            'classifier__batch_size': [10, 56]
        }
    ) 
}

# %%
# Generic Cross Validation adapted to Pipelines
def generic_grid_search(pipeline, params, X_matrix, y_matrix):
    """
    Generic wrapper for GridSearchCV adapted to work with sklearn Pipeline objects.
    Performs hyperparameter tuning via cross-validation using ROC_AUC as the scoring metric.

    Args:
        pipeline: sklearn Pipeline object containing preprocessor and classifier steps.
        params (dict): Parameter grid for GridSearchCV containing hyperparameters to tune.
        X_matrix: Feature matrix for training.
        y_matrix: Target vector for training.

    Returns:
        tuple: Contains best_params (dict of optimal hyperparameters) and estimator_name (str).
    """
    
    grid = GridSearchCV(pipeline, param_grid=params, cv=5, scoring='roc_auc')
    grid.fit(X_matrix, y_matrix)

    best_params = grid.best_params_
    # best_estimator = grid.best_estimator_
    estimator_name = pipeline.steps[-1][1].__class__.__name__
    
    return best_params, estimator_name

# %%
best_params_results = {}

for model_name, (pipeline, params) in pipes_and_params.items():
    print(f'Tuning model: {model_name}')
    
    try:
        best_params, estimator_name = generic_grid_search(
            pipeline=pipeline,
            params=params,
            X_matrix=X_train,
            y_matrix=y_train
        )
        
        best_params_results[f'{estimator_name}'] = (pipeline, best_params)
        
    except Exception as e:
        print(f'Error while tunning: {model_name}')
        traceback.print_exc()
    else:
        print(f'Successfully found {model_name} best params')
        print(f'Pipeline and best params saved in {best_params_results}')
        print()
        
best_params_results
# Out:
# Tuning model: DecisionTreeClassifier
# Successfully found DecisionTreeClassifier best params
# Pipeline and best params saved in {'DecisionTreeClassifier': (Pipeline(steps=[('prep',
#                  ColumnTransformer(transformers=[('categorical',
#                                                   OrdinalEncoder(handle_unknown='use_encoded_value',
#                                                                  unknown_value=-1),
#                                                   ['sex', 'cp', 'fbs',
#                                                    'restecg', 'exang', 'slope',
#                                                    'ca', 'thal']),
#                                                  ('numerical', 'passthrough',
#                                                   ['age', 'trestbps', 'chol',
#                                                    'thalach', 'oldpeak'])])),
# ...

# %%
from datetime import date
current_date = date.today().strftime('%Y-%m-%d')

# Save the "best_params" dictionary in memory
with open(f'../data/raw/best_params_results_{current_date}.pkl', 'wb') as f:
    pickle.dump(best_params_results, f)

# %% [markdown]
# ---

# %% [markdown]
# ## Tracking de modelos via MLflow

# %%
# Setting up MLflow's tracking ui
mlflow.set_tracking_uri(uri='http://localhost:5000')
# Setting up experiment's name
response = mlflow.set_experiment('Heart disease pipeline experiment')
# Out:
# 2026/04/02 13:52:25 INFO mlflow.tracking.fluent: Experiment with name 'Heart disease pipeline experiment' does not exist. Creating a new experiment.

# %% [markdown]
# ### Generic function for training and registering models.

# %%
def train_and_log_model(pipeline, params, X_train, X_test, y_train, y_test, dataset, dataset_path):
    """
    Generic model registration function for MLflow.
    
    This is a generic function to register models to MLflow. It receives the classifier, X and Y matrices, the specific parameters
    for the model (estimator), the dataset used in its training, and the path to the dataset file in the project.
    Its functionality is to train the model and perform its run registration in MLflow, in addition to registering other information such as:
    parameters, metrics (accuracy, precision, recall & f1-score), input example, model signature, and the dataset used.
    
    Args:
        pipeline: Scikit-Learn Pipeline object containing preprocessor and classifier steps.
        params (dict): Dictionary of best parameters chosen via GridSearchCV.
        X_train (numpy.ndarray): Feature matrix used for training.
        y_train (numpy.ndarray): Vector or matrix of target labels for training.
        X_test (numpy.ndarray): Feature matrix used for testing.
        y_test (numpy.ndarray): Vector or matrix of target labels for testing.
        dataset (pandas.core.frame.DataFrame): The dataset used for model training.
        dataset_path (str): Path to the dataset file in the project.
    
    Returns:
        model_info: Information returned after tracking the model in MLflow.
    """
    
    mlflow_dataset = mlflow.data.from_pandas(
        dataset, 
        source=dataset_path,
        name=dataset_path.split('/')[-1]
    )
    
    # Get the name of the estimator (last step in the pipeline)
    estimator_name = pipeline.steps[-1][1].__class__.__name__
    print('Name of the model: ' + estimator_name)
    

    with mlflow.start_run(run_name=estimator_name):
        
        # Model training
        # Set the best pparams as the params of the pipeline
        pipeline.set_params(**params)
        pipeline.fit(X_train, y_train)
        # Pipeline forecast
        y_pred = pipeline.predict(X_test)
        y_pred_proba = pipeline.predict_proba(X_test)
        
        # Record in MLflow 
        # Parameter registration
        mlflow.log_params(params)
        
        # Key metrics registration
        mlflow.log_metric('ROC_AUC', roc_auc_score(y_test, y_pred_proba[:, 1]))
        mlflow.log_metric('Accuracy', accuracy_score(y_test, y_pred))
        mlflow.log_metric('Precision', precision_score(y_test, y_pred))
        mlflow.log_metric('Recall', recall_score(y_test, y_pred))
        mlflow.log_metric('f1 score', f1_score(y_test, y_pred))
        
        # Dataset registration
        mlflow.log_input(mlflow_dataset, context='raw-data')
        
        # Tags registration
        mlflow.set_tag('Training info', f'Basic {estimator_name} for heart disease data')
        mlflow.set_tag('Model origin', 'Generic function for training and registering model.')
        
        signature = infer_signature(X_train, pipeline.predict(X_test))
        
        # Registration of the model itself
        # The variable `model_info` contains information returned after tracking the model
        model_info = mlflow.sklearn.log_model(
            name=estimator_name,
            sk_model=pipeline,
            signature=signature, 
            input_example=X_test.iloc[[0]],
            registered_model_name=estimator_name
        )
        
        return model_info

# %%
for model_name, (pipeline, param) in best_params_dict.items():
    print(f'Model: {model_name}')
    try:
        model_tacking = train_and_log_model(
            pipeline,
            param, 
            X_train, 
            X_test,
            y_train,
            y_test,
            dataset,
            dataset_path
        )
    except Exception as e:
        print(f'Error: {e}')
        traceback.print_exc()
    else:
        print(f'Successfully trained and registered model: {model_name}')
        print(f'Artifact path: {model_tacking.artifact_path}')
        print()
# Out:
# model: DecisionTreeClassifier_best_params
# Nome do modelo: DecisionTreeClassifier
# /home/gustavoalves/Documents/Github/mlops_project/venv/lib/python3.10/site-packages/mlflow/data/dataset_source_registry.py:149: UserWarning: Failed to determine whether UCVolumeDatasetSource can resolve source information for '../data/raw/heart.csv'. Exception:
#   return _dataset_source_registry.resolve(
# /home/gustavoalves/Documents/Github/mlops_project/venv/lib/python3.10/site-packages/mlflow/data/dataset_source_registry.py:149: UserWarning: The specified dataset source can be interpreted in multiple ways: LocalArtifactDatasetSource, LocalArtifactDatasetSource. MLflow will assume that this is a LocalArtifactDatasetSource source.
#   return _dataset_source_registry.resolve(
# ...

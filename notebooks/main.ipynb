# %% [markdown]
# # Estudos Heart Disease Dataset

# %%
import pickle
import traceback
import pandas as pd
import mlflow
from mlflow.models import infer_signature
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, roc_auc_score
from sklearn.pipeline import Pipeline
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import OneHotEncoder, OrdinalEncoder, StandardScaler
from sklearn.model_selection import GridSearchCV
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC
from sklearn.neural_network import MLPClassifier

# %% [markdown]
# ## Sobre o dataset
#
# **Significado dos dados em cada coluna:**
#
# - **age**: Idade do paciente.
# - **sex**: Sexo do paciente.
# - **cp (chest pain type)**: Tipo de dor no peito. Valores possíveis: 0, 1, 2 ou 3.
# - **trestbps (resting blood pressure)**: Pressão sanguínea do paciente quando em repouso.
# - **chol (serum cholesterol in mg/dl)**: Nível total de colesterol no sangue (em mg/dl).
# - **fbs (fasting blood sugar > 120 mg/dl)**: Quantidade de açúcar no sangue após 8 horas de jejum. Se maior que 120 mg/dl, o valor é 1; caso contrário, 0.
# - **restecg (resting electrocardiographic results)**: Resultados do eletrocardiograma em repouso.
#   - 0 = Normal
#   - 1 = Pode indicar isquemia cardíaca (falta de oxigenação no coração)
#   - 2 = Anormalidades significativas, como hipertrofia ventricular esquerda (HVE), hipertensão, etc.
# - **thalach (maximum heart rate achieved)**: Maior valor de batimentos cardíacos por minuto registrado durante o exame.
# - **exang (exercise induced angina)**: Dor no peito induzida por exercício, causada por fluxo sanguíneo reduzido para o músculo cardíaco. Valores possíveis: 0 ou 1.
# - **oldpeak (ST depression induced by exercise relative to rest)**: Depressão no segmento ST do eletrocardiograma (ECG), observada durante o exercício em comparação com o repouso. Pode indicar a presença de Doença Arterial Coronária (DAC).
# - **slope (the slope of the peak exercise ST segment)**: Inclinação do segmento ST no ECG durante o pico do exercício.
# - **ca (number of major vessels colored by fluoroscopy)**: Número de vasos sanguíneos principais visíveis durante um exame de fluoroscopia, uma técnica de imagem médica que utiliza raios-X em tempo real. Valores possíveis: 0, 1, 2 ou 3.
# - **thal**: Resultados de exames que avaliam o fluxo sanguíneo para o coração.
#   - 0 = Normal
#   - 1 = Defeito fixo (fluxo permanentemente prejudicado)
#   - 2 = Defeito reversível (fluxo temporariamente prejudicado, mas recuperável)
# - **target**: Indica a presença de doença cardíaca no paciente.
#   - 0 = Sem doença
#   - 1 = Doente

# %% [markdown]
# ---

# %% [markdown]
# ## Base de dados & Data understanding básico

# %%
# Leitura da base
dataset_path = '../data/raw/heart.csv'
dataset = pd.read_csv(dataset_path)
# Sanity test - 5 primeiros registros
dataset.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   52    1   0       125   212    0        1      168      0      1.0      2
# 1   53    1   0       140   203    1        0      155      1      3.1      0
# 2   70    1   0       145   174    0        1      125      1      2.6      0
# 3   61    1   0       148   203    0        1      161      0      0.0      2
# 4   62    0   0       138   294    1        1      106      0      1.9      1
#
#    ca  thal  target
# 0   2     3       0
# 1   0     3       0
# 2   0     3       0
# 3   1     3       0
# 4   3     2       0

# %%
with open('../data/raw/best_params.pkl', 'rb') as f:
    best_params_dict = pickle.load(f)

# %%
best_params_dict
# Out:
# {'DecisionTreeClassifier_best_params': (Pipeline(steps=[('prep',
#                    ColumnTransformer(transformers=[('categorical',
#                                                     OrdinalEncoder(handle_unknown='use_encoded_value',
#                                                                    unknown_value=-1),
#                                                     ['sex', 'cp', 'fbs',
#                                                      'restecg', 'exang', 'slope',
#                                                      'ca', 'thal']),
#                                                    ('numerical', 'passthrough',
#                                                     ['age', 'trestbps', 'chol',
#                                                      'thalach', 'oldpeak'])])),
#                   ('classifier', DecisionTreeClassifier(splitter='random'))]),
#   {'classifier__criterion': 'gini',
#    'classifier__min_samples_leaf': 1,
# ...

# %%
dataset.columns
# Out:
# Index(['age', 'sex', 'cp', 'trestbps', 'chol', 'fbs', 'restecg', 'thalach',
#        'exang', 'oldpeak', 'slope', 'ca', 'thal', 'target'],
#       dtype='object')

# %%
dataset.shape
# Out:
# (1025, 14)

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1025 entries, 0 to 1024
# Data columns (total 14 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       1025 non-null   int64
#  1   sex       1025 non-null   int64
#  2   cp        1025 non-null   int64
#  3   trestbps  1025 non-null   int64
#  4   chol      1025 non-null   int64
#  5   fbs       1025 non-null   int64
#  6   restecg   1025 non-null   int64
#  7   thalach   1025 non-null   int64
#  8   exang     1025 non-null   int64
#  9   oldpeak   1025 non-null   float64
#  10  slope     1025 non-null   int64
#  11  ca        1025 non-null   int64
#  12  thal      1025 non-null   int64
#  13  target    1025 non-null   int64
# dtypes: float64(1), int64(13)
# memory usage: 112.2 KB

# %%
X = dataset.iloc[:, 0:13]
y = dataset.iloc[:, 13]

# %%
# Divisão treino-teste
X_train, X_test,  y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=0)

# %%
y_train.shape
# Out:
# (820,)

# %%
y_test.shape
# Out:
# (205,)

# %% [markdown]
# ## Pipelines
# Criar uma pipeline para cada tipo específico de modelo, com transformação de escala ideal para cada.

# %%
# Separação de colunas numéricas e categóricas
numerical_cols = ['age', 'trestbps', 'chol', 'thalach', 'oldpeak']
categorical_cols = []
for col in dataset.columns:
    if col in numerical_cols or col == 'target':
        continue
    categorical_cols.append(col)

# %%
categorical_cols
# Out:
# ['sex', 'cp', 'fbs', 'restecg', 'exang', 'slope', 'ca', 'thal']

# %%
# Decision Tree, Random Forest, Gradient Boosting
prep_tree = ColumnTransformer(
    transformers=[
        ('categorical', OrdinalEncoder(
            handle_unknown='use_encoded_value',
            unknown_value=-1  # obrigatório quando handle_unknown='use_encoded_value'
        ), categorical_cols),
        ('numerical', 'passthrough', numerical_cols)
    ]
)

# KNN
prep_knn = ColumnTransformer(
    transformers=[
        ('categorical', OneHotEncoder(
            handle_unknown='use_encoded_value'), categorical_cols),
        ('numerical', StandardScaler(), numerical_cols)
    ]
)

# Logistic Regressor, SVC, MLPClassifier
prep_linear = ColumnTransformer(
    transformers=[
        ('categorical', OneHotEncoder(handle_unknown='ignore'), categorical_cols),
        ('numerical', StandardScaler(), numerical_cols)
    ]
)

# %% [markdown]
# ---

# %% [markdown]
# ## Cross validation / Tunning de hiperparâmetros

# %%
pipes_and_params = {
        'DecisionTreeClassifier': (
            Pipeline([
                ('prep', prep_tree), 
                ('classifier', DecisionTreeClassifier())
        ]),{
            'classifier__criterion': ['gini', 'entropy'],
            'classifier__splitter': ['best', 'random'],
            'classifier__min_samples_split': [2, 5, 10],
            'classifier__min_samples_leaf': [1, 5, 10]
        }
    ),
        'RandomForestClassifier': (
            Pipeline([
                ('prep', prep_tree), 
                ('classifier', RandomForestClassifier())
        ]),{
            'classifier__criterion': ['gini', 'entropy'],
            'classifier__n_estimators': [10, 40, 100, 150],
            'classifier__min_samples_split': [2, 5, 10],
            'classifier__min_samples_leaf': [1, 5, 10]
        }
    ),
        'GradientBoostingClassifier': (
            Pipeline([
                ('prep', prep_tree), 
                ('classifier', GradientBoostingClassifier())
        ]), {
            'classifier__loss': ['log_loss', 'exponential'],
            'classifier__learning_rate': [0.1, 0.01, 0.001, 0.0001],
            'classifier__n_estimators': [25, 50, 100, 200, 300, 500],
            'classifier__criterion': ['friedman_mse', 'squared_error']
        }
    ),
        'KNN': (
            Pipeline([
                ('prep', prep_linear), 
                ('classifier', KNeighborsClassifier())
        ]),{
            'classifier__n_neighbors': [3, 5, 10, 20],
            'classifier__p': [1, 2]
        }
    ),
        'LogisticRegression': (
            Pipeline([
                ('prep', prep_linear), 
                ('classifier', LogisticRegression(max_iter=2000))
        ]),{
            'classifier__tol': [0.0001, 0.00001, 0.000001],
            'classifier__C': [1.0, 1.5, 2.0],
            'classifier__solver': ['lbfgs', 'sag', 'saga']
        }
    ),
        'SVC': (
            Pipeline([
                ('prep', prep_linear), 
                ('classifier', SVC(probability=True))
        ]),{
            'classifier__tol': [0.001, 0.0001, 0.00001],
            'classifier__C': [1.0, 1.5, 2.0],
            'classifier__kernel': ['rbf', 'linear', 'poly', 'sigmoid']
        }
    ),
        'MLPC': (
        Pipeline([
            ('prep', prep_linear), 
            ('classifier', MLPClassifier(max_iter=3500))
        ]),{
            'classifier__activation': ['relu', 'logistic', 'tanh'],
            'classifier__solver': ['adam', 'sgd'],
            'classifier__batch_size': [10, 56]
        }
    ) 
}

# %%
# pipeline_best_params = {}
# for pipeline, param in zip(pipes_and_params.values(), best_params_dict.values()):
#         pipeline_best_params[pipeline[0].steps[-1][1].__class__.__name__] = (pipeline[0], param)

# %%
# Generic Cross Validation Function to Pipelines
def generic_grid_search(pipeline, params, X_matrix, y_matrix):
    
    grid = GridSearchCV(pipeline, param_grid=params, cv=5, scoring='roc_auc')
    grid.fit(X_matrix, y_matrix)

    best_params = grid.best_params_
    # best_estimator = grid.best_estimator_
    estimator_name = pipeline.steps[-1][1].__class__.__name__
    
    return best_params, estimator_name

# %%
best_params_dict = {}

for model_name, (pipeline, params) in pipes_and_params.items():
    print(f'Tunning model: {model_name}')
    
    try:
        best_params, estimator_name = generic_grid_search(
            pipeline=pipeline,
            params=params,
            X_matrix=X_train,
            y_matrix=y_train
        )
        
        best_params_dict[f'{model_name}_best_params'] = (pipeline, best_params)
        
    except Exception as e:
        print(f'Error while tunning: {model_name}')
        traceback.print_exc()
    else:
        print(f'Success!')
        print(f'Best params: {best_params}.')
        print()
# Out:
# Tunning model: DecisionTreeClassifier
# Success!
# Best params: {'classifier__criterion': 'gini', 'classifier__min_samples_leaf': 1, 'classifier__min_samples_split': 5, 'classifier__splitter': 'random'}.
#
# Tunning model: RandomForestClassifier
# Success!
# Best params: {'classifier__criterion': 'entropy', 'classifier__min_samples_leaf': 1, 'classifier__min_samples_split': 2, 'classifier__n_estimators': 150}.
#
# Tunning model: GradientBoostingClassifier
# Success!
# Best params: {'classifier__criterion': 'friedman_mse', 'classifier__learning_rate': 0.1, 'classifier__loss': 'log_loss', 'classifier__n_estimators': 500}.
#
# Tunning model: KNN
# Success!
# Best params: {'classifier__n_neighbors': 3, 'classifier__p': 1}.
#
# Tunning model: LogisticRegression
# Success!
# Best params: {'classifier__C': 2.0, 'classifier__solver': 'lbfgs', 'classifier__tol': 0.0001}.
#
# Tunning model: SVC
# Success!
# ...

# %%
mlpc_pipeline = pipes_and_params['MLPC'][0]
mlpc_params = pipes_and_params['MLPC'][1]

best_params, _ = generic_grid_search(mlpc_pipeline, mlpc_params, X_train, y_train)

print(best_params)
# Out:
# /home/gustavoalves/Documents/Github/mlops_project/venv/lib/python3.10/site-packages/sklearn/neural_network/_multilayer_perceptron.py:787: UserWarning: Training interrupted by user.
#   warnings.warn("Training interrupted by user.")

# %%
# Salvar o dicionário de melhores parâmetros

# with open('../data/raw/best_params.pkl', 'wb') as f:
#     pickle.dump(best_params_dict, f)

# %% [markdown]
# ---

# %% [markdown]
# ## Tracking de modelos via MLflow

# %%
# Definir o tracking ui
mlflow.set_tracking_uri(uri='http://localhost:5000')
# Definindo o experimento do registro
response = mlflow.set_experiment('Heart disease pipeline experiment')
# Out:
# 2026/04/02 13:52:25 INFO mlflow.tracking.fluent: Experiment with name 'Heart disease pipeline experiment' does not exist. Creating a new experiment.

# %% [markdown]
# ### Função genérica para treino e registro de modelos

# %%
def train_and_log_model(pipeline, params, X_train, X_test, y_train, y_test, dataset, dataset_path):

    """
    Função "genérica" de registro de modelos no MLflow.
    
    Esta é uma função genérica para registrar os modelos ao MLflow. Ela recebe o classificador, as matrizes X e Y, os parâmetros
    especificos do modelo (estimador), o dataset usado em seu treinamento e o caminho do dataset arquivo do dataset no projeto. 
    Sua funcionalidade se dá em treinar o modelo e fazer seu registro de sua run no MLflow, além de registrar outras informações como:
    parâmetros, métricas (accuracy, precision, recall & f1-score), exemplo de input, assinatura do modelo e o dataset usado.
    
    Args:
        estimator: Classificador do Scikit-Learn.
        X_train (numpy.ndarray): Matriz de features usada para o treinamento.
        y_train (numpy.ndarray): Vetor ou matriz de rótulos alvo para treinamento.
        X_test (numpy.ndarray): Matriz de features usada para o teste.
        y_test (numpy.ndarray): Vetor ou matriz de rótulos alvo para teste.
        params (dict): Dicionário de melhores parâmetros escolhidos via GridSearchCV.
        dataset (pandas.core.frame.DataFrame): 
    
    Returns:
        
    """
    
    mlflow_dataset = mlflow.data.from_pandas(
        dataset, 
        source=dataset_path,
        name=dataset_path.split('/')[-1]
    )
    
    estimator_name = pipeline.steps[-1][1].__class__.__name__
    print('Nome do modelo: ' + estimator_name)
    
    # Wrapper de run
    with mlflow.start_run(run_name=estimator_name):
        
        # Treinamento do modelo
        # Obter o atributo nome do estimador

        # Instânciar do estimador com os parâmetros escolhidos
        # estimator = estimator(**params)
        pipeline.set_params(**params)
        # Fitagem dos dados no algoritmo
        pipeline.fit(X_train, y_train)
        # Inferência do modelo
        y_pred = pipeline.predict(X_test)
        y_pred_proba = pipeline.predict_proba(X_test)
        
        # Registro no MLflow
        # Registro dos parâmetros
        mlflow.log_params(params)
        
        # Registro das métricas principais
        mlflow.log_metric('ROC_AUC', roc_auc_score(y_test, y_pred_proba[:, 1]))
        mlflow.log_metric('Accuracy', accuracy_score(y_test, y_pred))
        mlflow.log_metric('Precision', precision_score(y_test, y_pred))
        mlflow.log_metric('Recall', recall_score(y_test, y_pred))
        mlflow.log_metric('f1 score', f1_score(y_test, y_pred))
        
        # Registro do Dataset
        mlflow.log_input(mlflow_dataset, context='raw-data')
        
        # Registro de tags para fins de documentação
        mlflow.set_tag('Training info', f'Basic {estimator_name} for heart disease data')
        mlflow.set_tag('Model origin', 'train and log models function')
        
        signature = infer_signature(X_train, pipeline.predict(X_test))
        
        # Registro do modelo em si
        # A variável model_info contém informações retornadas após o tracking do modelo
        model_info = mlflow.sklearn.log_model(
            name=estimator_name,
            sk_model=pipeline,
            signature=signature, 
            input_example=X_test.iloc[[0]],
            registered_model_name=estimator_name
        )
        
        return model_info

# %%
for model_name, (pipeline, param) in best_params_dict.items():
    print(f'model: {model_name}')
    try:
        model_tacking = train_and_log_model(
            pipeline,
            param, 
            X_train, 
            X_test,
            y_train,
            y_test,
            dataset,
            dataset_path
        )
    except Exception as e:
        print(f'Error: {e}')
        traceback.print_exc()
    else:
        print(f'Successfully trained and registered model {model_name}')
        print(f'artifact path: {model_tacking.artifact_path}')
        print()
# Out:
# model: DecisionTreeClassifier_best_params
# Nome do modelo: DecisionTreeClassifier
# /home/gustavoalves/Documents/Github/mlops_project/venv/lib/python3.10/site-packages/mlflow/data/dataset_source_registry.py:149: UserWarning: Failed to determine whether UCVolumeDatasetSource can resolve source information for '../data/raw/heart.csv'. Exception:
#   return _dataset_source_registry.resolve(
# /home/gustavoalves/Documents/Github/mlops_project/venv/lib/python3.10/site-packages/mlflow/data/dataset_source_registry.py:149: UserWarning: The specified dataset source can be interpreted in multiple ways: LocalArtifactDatasetSource, LocalArtifactDatasetSource. MLflow will assume that this is a LocalArtifactDatasetSource source.
#   return _dataset_source_registry.resolve(
# ...
